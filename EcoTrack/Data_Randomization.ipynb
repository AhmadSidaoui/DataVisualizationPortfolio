# %% [markdown]
# # Dependencies

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import pandas as pd
import random
import time

# %% [markdown]
# # Retrieve the dataframes from sources

# %%
import pandas as pd
import random


df_dim_static = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'Dim - Static')
df_sortation_material_type = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'Sortation Material Type')
df_units_installed = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'units installed')
df_orders = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'Replynish - Orders')
df_sortation_data = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'fact - Sortation Data')
df_financial_cost = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'Financial - Cost')
df_financial_sales = pd.read_excel("Cru3 Data.xlsx", sheet_name = 'Financial - Sales')

# %% [markdown]
# # Fucntions

# %% [markdown]
# ## Geo-location boundaries

# %%
VIENNA_LAT_MIN, VIENNA_LAT_MAX = 46.36, 49.02
VIENNA_LON_MIN, VIENNA_LON_MAX = 9.53, 17.16

# %% [markdown]
# ## Fucntions

# %%
geolocator = Nominatim(user_agent="vienna_fix", timeout=10)


def swap_characters(entity):
    swapped = ''
    for char in entity:
        if char.isdigit():
            swapped += chr(ord('A') + int(char))  # 0 -> A, 1 -> B, ..., 9 -> J
        elif char.isalpha():
            swapped += str(ord(char.upper()) - ord('A'))  # A -> 0, B -> 1, ..., Z -> 25
        else:
            swapped += char
    return swapped

def is_within_vienna(lat, lon):
    return VIENNA_LAT_MIN <= lat <= VIENNA_LAT_MAX and VIENNA_LON_MIN <= lon <= VIENNA_LON_MAX

def generate_random_vienna_coord():
    return (
        random.uniform(VIENNA_LAT_MIN, VIENNA_LAT_MAX),
        random.uniform(VIENNA_LON_MIN, VIENNA_LON_MAX)
    )

def reverse_geocode_vienna(lat, lon):
    try:
        location = geolocator.reverse((lat, lon), language='en')
        if location and location.raw:
            address = location.raw.get('address', {})
            return {
                'state': address.get('state', ''),
                'location address': location.address,
                'city': address.get('city', '') or address.get('town', '') or address.get('village', ''),
                'Region': address.get('region', ''),
                'Region Name': address.get('county', '') or address.get('state_district', '')
            }
    except Exception:
        return {}
    return {}
def relocate_to_vienna(row):
    if not is_within_vienna(row['lat'], row['lon']):
        new_lat, new_lon = generate_random_vienna_coord()
        row['lat'] = new_lat
        row['lon'] = new_lon

        metadata = reverse_geocode_vienna(new_lat, new_lon)
        for key, value in metadata.items():
            row[key] = value
        
        time.sleep(1)  # prevent API throttling
    return row

# %% [markdown]
# # Tables

# %% [markdown]
# ## Dim Static

# %%
# Entity randomization
sampled_entities = df_dim_static['Entity'].sample(20, random_state=42).tolist()
df_dim_static = df_dim_static[df_dim_static['Entity'].isin(sampled_entities)]
df_dim_static["Entity"] = df_dim_static["Entity"].apply(swap_characters)
df_dim_static["account name"] = df_dim_static["account name"].apply(swap_characters)

# Geozone relocation
df_dim_static = df_dim_static.apply(relocate_to_vienna, axis=1)
df_dim_static['Region'] = df_dim_static['Region Name']
df_dim_static['fulfillment party'] = 'Company X'
df_dim_static['Alias'] = df_dim_static['Entity']

# Numerical data
df_dim_static['Weeks in Service'] = df_dim_static['Weeks in Service'].apply(lambda x: round(x * random.uniform(0.7, 0.9), 0) if pd.notnull(x) else x)
df_dim_static['Pick-up Frequency'] = df_dim_static['Pick-up Frequency'].apply(lambda x: round(x * random.uniform(0.7, 0.9), 2) if pd.notnull(x) else x)

# Unavailable data
df_dim_static = df_dim_static.replace("", "Not Available")
df_dim_static = df_dim_static.fillna("Not Available")

df_dim_static.reset_index(drop=True, inplace=True)
df_dim_static
# Out:
#    Entity        lat        lon                           state  \
# 0    0013  48.261501  10.305468                         Bavaria
# 1    0073  47.129519  12.752954                        Salzburg
# 2    0100  47.203268  10.882400                           Tyrol
# 3    0247  47.458145   9.681256                      Vorarlberg
# 4    0331  48.576235  16.750478                   Lower Austria
# 5    0374  46.950896  15.974936                          Styria
# 6    0489  48.058176  10.674465                         Bavaria
# 7    0839  47.711069  12.476257                         Bavaria
# 8    1342  47.129639  16.324468                      Burgenland
# 9    4808  47.852778  15.451209                   Lower Austria
# 10   5810  46.774822  12.013312  Trentino – Alto Adige/Südtirol
# 11   6246  46.812754  10.009189                         Grisons
# 12   6376  47.261646  10.574535                           Tyrol
# 13   6482  47.256869  13.471028                        Salzburg
# 14   6502  47.486941  15.185161                          Styria
# 15   8114  48.315110  13.163583                         Bavaria
# 16   8181  48.416983  15.570872                   Lower Austria
# 17   8226  48.561715  10.142634               Baden-Württemberg
# 18   8259  46.554894  12.452892                          Veneto
# 19   8282  48.880514  12.443054                         Bavaria
#
#                                      location address fulfillment party  \
# 0   St 2019, Glaserhof, Kiesberg, Deisenhausen, Kr...         Company X
# 1   Hohe Dock Steig, Fusch an der Großglocknerstra...         Company X
# 2   Hauptstraße, Oetzerau, Oetz, Bezirk Imst, Tyro...         Company X
# 3   Königswiesen, Lustenau, Bezirk Dornbirn, Vorar...         Company X
# 4   Am Steinberg, Katastralgemeinde Gösting, Ziste...         Company X
# 5   Johnsdorferstraße, Johnsdorf, Fehring, Bezirk ...         Company X
# 6   13, Pirmin-Klaunzler-Straße, Amberg, Verwaltun...         Company X
# 7   B 305, Brem, Oberwössen, Unterwössen, Landkrei...         Company X
# 8   Punitzer Straße, Pagelberg, Punitz, Tobaj, Bez...         Company X
# 9   Sandbühel, Katastralgemeinde Weidenaurotte, Tü...         Company X
# 10  Pustertaler Radweg - Pista Ciclabile Val Puste...         Company X
# 11    Klosters, Prättigau/Davos, Grisons, Switzerland         Company X
# 12   Bockkar, Imst, Bezirk Imst, Tyrol, 6460, Austria         Company X
# 13              Tauernkarleitenalm, Salzburg, Austria         Company X
# 14  10, Hüttengraben, Tragöß-Sankt Katharein, Bezi...         Company X
# 15  Ernegg, Ering, Ering (VGem), Landkreis Rottal-...         Company X
# 16  Gründlweg, Alauntal, Katastralgemeinde Egelsee...         Company X
# 17  A 7, Bissingen ob Lontal, Herbrechtingen, Land...         Company X
# 18  Via della Grotta, Villapiccola, Auronzo di Cad...         Company X
# 19  Ochsenstraße, Radldorf, Perkam, Rain (VGem), L...         Company X
#
#    account name Alias                     Region  Weeks in Service  \
# 0          CCBC  0013         Landkreis Günzburg              16.0
# 1          CCBC  0073         Bezirk Zell am See              49.0
# 2          CCBC  0100                Bezirk Imst              67.0
# 3          CCBC  0247            Bezirk Dornbirn              56.0
# 4          CCBC  0331         Bezirk Gänserndorf              22.0
# 5          CCBC  0374    Bezirk Südoststeiermark              38.0
# 6          CCBC  0489      Landkreis Unterallgäu              28.0
# 7          CCBC  0839       Landkreis Traunstein              21.0
# 8          CCBC  1342             Bezirk Güssing              32.0
# 9           BIC  4808          Bezirk Lilienfeld              60.0
# 10         CCBC  5810                South Tyrol              55.0
# 11          BIC  6246            Prättigau/Davos              50.0
# 12          BIC  6376                Bezirk Imst              48.0
# 13          BIC  6482              Not Available              48.0
# 14          BIC  6502  Bezirk Bruck-Mürzzuschlag              64.0
# 15          BIC  8114       Landkreis Rottal-Inn              32.0
# 16          BIC  8181              Not Available              30.0
# 17          BIC  8226       Landkreis Heidenheim              31.0
# 18          BIC  8259                    Belluno              19.0
# 19          BIC  8282  Landkreis Straubing-Bogen              60.0
#
#     Pick-up Frequency  Population                              city  \
# 0                0.20       25464                      Deisenhausen
# 1                0.42       31578   Fusch an der Großglocknerstraße
# 2                0.59       38006                          Oetzerau
# 3                0.15        9148                          Lustenau
# 4                0.59       30299                       Zistersdorf
# 5                0.29       15955                           Fehring
# 6                1.18       20748                            Amberg
# 7                0.29       31423                        Oberwössen
# 8                1.23       50210                            Punitz
# 9                0.24       44822                           Türnitz
# 10               0.16       17853  Rasen-Antholz - Rasun-Anterselva
# 11               0.25       60667                          Klosters
# 12               0.06       12734                              Imst
# 13               0.07       68472                     Not Available
# 14               0.24       40001            Tragöß-Sankt Katharein
# 15               0.51       39926                             Ering
# 16               0.68       19165                Krems an der Donau
# 17               0.70       27797                    Herbrechtingen
# 18               0.03       53550                 Auronzo di Cadore
# 19               0.12       19530                          Radldorf
#
#                   Region Name
# 0          Landkreis Günzburg
# 1          Bezirk Zell am See
# 2                 Bezirk Imst
# 3             Bezirk Dornbirn
# 4          Bezirk Gänserndorf
# 5     Bezirk Südoststeiermark
# 6       Landkreis Unterallgäu
# 7        Landkreis Traunstein
# 8              Bezirk Güssing
# 9           Bezirk Lilienfeld
# 10                South Tyrol
# 11            Prättigau/Davos
# 12                Bezirk Imst
# 13              Not Available
# 14  Bezirk Bruck-Mürzzuschlag
# 15       Landkreis Rottal-Inn
# 16              Not Available
# 17       Landkreis Heidenheim
# 18                    Belluno
# 19  Landkreis Straubing-Bogen

# %% [markdown]
# ## Units

# %%
df_units_installed = df_units_installed[df_units_installed['Entity'].isin(sampled_entities)]
df_units_installed["Entity"] = df_units_installed["Entity"].apply(swap_characters)
df_units_installed.reset_index(drop=True, inplace=True)
df_units_installed
# Out:
#       Entity       Time  installed units
# 0       EIAI 2023-05-16                1
# 1       EIAI 2023-05-17                1
# 2       EIAI 2023-05-18                1
# 3       EIAI 2023-05-19                1
# 4       EIAI 2023-05-20                1
# ...      ...        ...              ...
# 10657   ICFJ 2025-07-26                1
# 10658   ICFJ 2025-07-27                1
# 10659   ICFJ 2025-07-28                1
# 10660   ICFJ 2025-07-29                1
# 10661   ICFJ 2025-07-30                1
#
# [10662 rows x 3 columns]

# %% [markdown]
# ## Orders

# %%
df_orders["Entity"] = df_orders["Entity"].astype(str)
df_orders = df_orders[df_orders['Entity'].isin(sampled_entities)]
df_orders["Entity"] = df_orders["Entity"].apply(swap_characters)

#numerical data
df_orders['Value'] = df_orders['Value'].apply(lambda x: round(x * random.uniform(0.7, 1.3), 0) if pd.notnull(x) else x)
df_orders.reset_index(drop=True, inplace=True)
df_orders
# Out:
#      Entity       Date  fulfilled on Attribute.1  \
# 0      EIAI 2023-05-22           NaN   collected
# 1      EIAI 2023-05-30           NaN   collected
# 2      EIAI 2023-06-07           NaN   collected
# 3      EIAI 2023-06-15           NaN   collected
# 4      EIAI 2023-06-28           NaN   collected
# ...     ...        ...           ...         ...
# 2905   ICCG 2025-04-28           NaN   collected
# 2906   ICCG 2025-04-28           NaN   collected
# 2907   ICCG 2025-04-28           NaN   collected
# 2908   ICCG 2025-04-28           NaN   collected
# 2909   ICCG 2025-04-28           NaN   collected
#
#                                          Attribute.2  \
# 0                                      CRU3 - Orders
# 1                                      CRU3 - Orders
# 2                                      CRU3 - Orders
# 3                                      CRU3 - Orders
# 4                                      CRU3 - Orders
# ...                                              ...
# 2905            collected Polypropylene #5 (Plastic)
# 2906  collected HDPE #2 Containers - Mixed (Plastic)
# 2907      collected Aluminum Cans (Nonferrous Metal)
# 2908          collected PET #1 Thermoforms (Plastic)
# 2909                collected LDPE #4 Film (Plastic)
#
#                                  Attribute.3  Value
# 0                                        NaN    1.0
# 1                                        NaN    1.0
# 2                                        NaN    1.0
# 3                                        NaN    1.0
# 4                                        NaN    1.0
# ...                                      ...    ...
# 2905  collected Rigid Plastic Food Packaging    2.0
# 2906  collected Home Cleaning/Beauty Bottles    2.0
# 2907                      collected Aluminum    2.0
# 2908      collected Clear Plastic Containers    2.0
# 2909           collected Plastic Bags & Film    2.0
#
# [2910 rows x 7 columns]

# %% [markdown]
# ## Sortation Data

# %%
df_sortation_data["Entity"] = df_sortation_data["Entity"].astype(str)
df_sortation_data = df_sortation_data[df_sortation_data['Entity'].isin(sampled_entities)]
df_sortation_data["Entity"] = df_sortation_data["Entity"].apply(swap_characters)
df_sortation_data.reset_index(drop=True, inplace=True)

# numerical data
df_sortation_data['Weight'] = df_sortation_data['Weight'].apply(lambda x: round(x * random.uniform(0.1, 1.3), 0) if pd.notnull(x) else x)
df_sortation_data
# Out:
#      Entity       Time  Weight Weight Material Type.1  \
# 0      BDEC 2024-06-13     0.0              collected
# 1      BDEC 2024-06-27     0.0              collected
# 2      BDEC 2024-07-04     0.0              collected
# 3      BDEC 2024-07-18     0.0              collected
# 4      BDEC 2024-07-25     0.0              collected
# ...     ...        ...     ...                    ...
# 5673   ICIC 2025-03-05    86.0              collected
# 5674   ICIC 2025-04-23   118.0              collected
# 5675   ICIC 2025-05-07    28.0              collected
# 5676   ICIC 2025-07-09    57.0              collected
# 5677   ICIC 2025-07-23    87.0              collected
#
#                     Weight Material Type.2  \
# 0     collected Polypropylene #5 (Plastic)
# 1     collected Polypropylene #5 (Plastic)
# 2     collected Polypropylene #5 (Plastic)
# 3     collected Polypropylene #5 (Plastic)
# 4     collected Polypropylene #5 (Plastic)
# ...                                    ...
# 5673      collected LDPE #4 Film (Plastic)
# 5674      collected LDPE #4 Film (Plastic)
# 5675      collected LDPE #4 Film (Plastic)
# 5676      collected LDPE #4 Film (Plastic)
# 5677      collected LDPE #4 Film (Plastic)
#
#                       Weight Material Type.3
# 0     collected Rigid Plastic Food Packaging
# 1     collected Rigid Plastic Food Packaging
# 2     collected Rigid Plastic Food Packaging
# 3     collected Rigid Plastic Food Packaging
# 4     collected Rigid Plastic Food Packaging
# ...                                      ...
# 5673           collected Plastic Bags & Film
# 5674           collected Plastic Bags & Film
# 5675           collected Plastic Bags & Film
# 5676           collected Plastic Bags & Film
# 5677           collected Plastic Bags & Film
#
# [5678 rows x 6 columns]

# %% [markdown]
# ## Financial cost

# %%
df_financial_cost['Entity'] = 'Company X'
df_financial_cost = df_financial_cost[df_financial_cost['Key Column'] % 2 == 0]

# Numeric data
df_financial_cost['Amount'] = df_financial_cost['Amount'].apply(lambda x: round(x * random.uniform(0.1, 1.3), 2) if pd.notnull(x) else x)

# Source Number and Name
df_financial_cost['Source Number'] = df_financial_cost['Source Number'].apply(lambda x: f"SN-{random.randint(1000, 9999)}")
df_financial_cost['Source Name'] = df_financial_cost['Source Name'].apply(lambda x: f"Source {random.randint(1, 100)}")
df_financial_cost.reset_index(drop=True, inplace=True)

# Account Number
df_financial_cost['Account Numer'] = df_financial_cost['Account Numer'].apply(lambda x: f"AN-{random.randint(1000, 9999)}")
df_financial_cost
# Out:
#         Entity       Time  Key Column  Document Type Account Numer  \
# 0    Company X 2022-12-28     2420666              2       AN-5781
# 1    Company X 2022-12-28     2420688              2       AN-3211
# 2    Company X 2023-01-03     2496704              2       AN-5348
# 3    Company X 2023-01-05     2557156              2       AN-3597
# 4    Company X 2023-01-19     2638782              2       AN-2307
# ..         ...        ...         ...            ...           ...
# 276  Company X 2025-07-01    18847480              2       AN-6319
# 277  Company X 2025-06-29    18860116              2       AN-2553
# 278  Company X 2025-07-02    18860118              2       AN-1720
# 279  Company X 2025-07-03    18880310              2       AN-2884
# 280  Company X 2025-07-03    18880312              2       AN-7813
#
#     Source Number Source Name    Amount  Year       Date
# 0         SN-5358   Source 86    295.29  2022 2022-12-28
# 1         SN-2453   Source 98    157.79  2022 2022-12-28
# 2         SN-2015   Source 69     86.17  2023 2023-01-03
# 3         SN-3327    Source 2     26.18  2023 2023-01-05
# 4         SN-9783    Source 4     23.32  2023 2023-01-19
# ..            ...         ...       ...   ...        ...
# 276       SN-2552    Source 1     22.98  2025 2025-07-01
# 277       SN-9799   Source 25   1964.25  2025 2025-06-29
# 278       SN-2507   Source 89  12210.77  2025 2025-07-02
# 279       SN-3659   Source 65   5175.22  2025 2025-07-03
# 280       SN-2971   Source 33   3665.16  2025 2025-07-03
#
# [281 rows x 10 columns]

# %% [markdown]
# ## Financial Sales

# %%
df_financial_sales['Entity'] = 'Company X'
df_financial_sales = df_financial_sales[df_financial_sales['Key Column'] % 2 == 0]

# Numeric data
df_financial_sales['Amount'] = df_financial_sales['Amount'].apply(lambda x: round(x * random.uniform(0.1, 1.3), 2) if pd.notnull(x) else x)

# Source Number and Name
df_financial_sales['Facility Code'] = df_financial_sales['Facility Code'].apply(lambda x: f"FC-{random.randint(1000, 9999)}")
df_financial_sales['Customer Name'] = df_financial_sales['Customer Name'].apply(lambda x: f"Source {random.randint(1, 100)}")
df_financial_sales.reset_index(drop=True, inplace=True)

# Account Number
df_financial_sales['Account Number'] = df_financial_sales['Account Number'].apply(lambda x: f"AN-{random.randint(1000, 9999)}")
df_financial_sales
# Out:
#        Entity       Time  Key Column  Document Type     Amount Account Number  \
# 0   Company X 2022-12-16     2353370              2   35191.45        AN-7176
# 1   Company X 2022-12-16     2353432              2   28364.09        AN-7691
# 2   Company X 2023-04-01     3338736              2    7398.59        AN-8224
# 3   Company X 2023-04-27     3429854              2  270410.20        AN-3540
# 4   Company X 2023-08-28     4686278              2    5904.01        AN-7670
# ..        ...        ...         ...            ...        ...            ...
# 62  Company X 2024-12-31    17136944              0   -1167.57        AN-5951
# 63  Company X 2025-05-14    18305342              2    2503.82        AN-4973
# 64  Company X 2025-05-21    18306630              2     240.71        AN-9054
# 65  Company X 2025-06-11    18327690              2     435.01        AN-6419
# 66  Company X 2025-07-18    19350256              2    7932.73        AN-7026
#
#    Facility Code Customer Name  Year     Month       Date
# 0        FC-8325     Source 96  2022  December 2022-12-16
# 1        FC-2200     Source 99  2022  December 2022-12-16
# 2        FC-4661     Source 95  2023     April 2023-04-01
# 3        FC-5816      Source 3  2023     April 2023-04-27
# 4        FC-7229      Source 7  2023    August 2023-08-28
# ..           ...           ...   ...       ...        ...
# 62       FC-5539     Source 98  2024  December 2024-12-31
# 63       FC-8134     Source 91  2025       May 2025-05-14
# 64       FC-6486     Source 20  2025       May 2025-05-21
# 65       FC-2092     Source 65  2025      June 2025-06-11
# 66       FC-1942     Source 73  2025      July 2025-07-18
#
# [67 rows x 11 columns]

# %% [markdown]
# # Saving to Excel

# %%
with pd.ExcelWriter("D6 Inc randomized data.xlsx", engine="xlsxwriter") as writer:
    df_dim_static.to_excel(writer, sheet_name="Dim - Static", index=False)
    df_sortation_material_type.to_excel(writer, sheet_name="Sortation Material Type", index=False)
    df_units_installed.to_excel(writer, sheet_name="units installed", index=False)
    df_orders.to_excel(writer, sheet_name="Replynish - Orders", index=False)
    df_sortation_data.to_excel(writer, sheet_name="fact - Sortation Data", index=False)
    df_financial_cost.to_excel(writer, sheet_name="Financial - Cost", index=False)
    df_financial_sales.to_excel(writer, sheet_name="Financial - Sales", index=False)
